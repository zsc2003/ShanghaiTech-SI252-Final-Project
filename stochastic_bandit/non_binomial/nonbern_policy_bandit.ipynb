# %% [markdown]
# ## Vanilla MABs 20 arms

# %%
import numpy as np
from nonbern_bandit_algorithms import UCB_Algorithm, Gradient_Bandit_Algorithm
from nonbern_bandit_algorithms import report_regrets
N, T = 50000, 100

# set seed
np.random.seed(0)

K = 20
theta_oracled = [(0.85,0.1),(0.8,0.1),(0.75,0.1),(0.7,0.1),(0.65,0.1),(0.6,0.1),(0.55,0.1),(0.5,0.1),(0.45,0.1),(0.4,0.1),(0.35,0.15),(0.3,0.15),(0.25,0.15),(0.2,0.15),(0.15,0.15),(0.1,0.15),(0.08,0.12),(0.06,0.1),(0.04,0.08),(0.02,0.06)]

vanilla_ucb_20 = UCB_Algorithm(N=N, T=T, theta_oracled=theta_oracled, c_list=[1], trajectory_path=None)
vanilla_gradient_bandit_20 = Gradient_Bandit_Algorithm(N=N, T=T, theta_oracled=theta_oracled, b_beta_list=[(-1, 0.5)], trajectory_path=None)

vanilla_ucb_20()
vanilla_gradient_bandit_20()
report_regrets([vanilla_ucb_20])
report_regrets([vanilla_gradient_bandit_20])
# Out:
# Running UCB Algorithm...
# 100%|██████████| 100/100 [00:38<00:00,  2.59it/s]
# Running Gradient Bandit Algorithm...
# 100%|██████████| 100/100 [01:06<00:00,  1.50it/s]

# %% [markdown]
# ## Vanilla MABs 25 arms

# %%
import numpy as np
from nonbern_bandit_algorithms import UCB_Algorithm, Gradient_Bandit_Algorithm
from nonbern_bandit_algorithms import report_regrets
N, T = 50000, 100

# set seed
np.random.seed(0)

K = 25
theta_oracled = [(0.88,0.07),(0.85,0.07),(0.82,0.07),(0.79,0.07),(0.76,0.07),(0.73,0.07),(0.7,0.1),(0.67,0.1),(0.64,0.1),(0.61,0.1),(0.58,0.1),(0.55,0.1),(0.52,0.1),(0.49,0.1),(0.46,0.1),(0.43,0.1),(0.4,0.15),(0.35,0.15),(0.3,0.15),(0.25,0.15),(0.2,0.15),(0.15,0.15),(0.1,0.1),(0.06,0.08),(0.03,0.05)]


vanilla_ucb_25 = UCB_Algorithm(N=N, T=T, theta_oracled=theta_oracled, c_list=[1], trajectory_path=None)
vanilla_gradient_bandit_25 = Gradient_Bandit_Algorithm(N=N, T=T, theta_oracled=theta_oracled, b_beta_list=[(-1, 0.5)], trajectory_path=None)

vanilla_ucb_25()
vanilla_gradient_bandit_25()
report_regrets([vanilla_ucb_25])
report_regrets([vanilla_gradient_bandit_25])
# Out:
# Running UCB Algorithm...
# 100%|██████████| 100/100 [00:38<00:00,  2.59it/s]
# Running Gradient Bandit Algorithm...
# 100%|██████████| 100/100 [01:09<00:00,  1.44it/s]

# %% [markdown]
# ## Vanilla MABs 30 arms

# %%
import numpy as np
from nonbern_bandit_algorithms import UCB_Algorithm, Gradient_Bandit_Algorithm
from nonbern_bandit_algorithms import report_regrets
N, T = 50000, 100

# set seed
np.random.seed(0)

K = 30
theta_oracled = [(0.9,0.05),(0.87,0.05),(0.84,0.05),(0.81,0.05),(0.78,0.05),(0.75,0.05),(0.72,0.05),(0.69,0.07),(0.66,0.07),(0.63,0.07),(0.6,0.07),(0.57,0.07),(0.54,0.07),(0.51,0.07),(0.48,0.1),(0.45,0.1),(0.42,0.1),(0.39,0.1),(0.36,0.1),(0.33,0.1),(0.3,0.1),(0.27,0.1),(0.24,0.1),(0.21,0.1),(0.18,0.1),(0.15,0.1),(0.12,0.08),(0.09,0.08),(0.06,0.06),(0.03,0.04)]


vanilla_ucb_30 = UCB_Algorithm(N=N, T=T, theta_oracled=theta_oracled, c_list=[1], trajectory_path=None)
vanilla_gradient_bandit_30 = Gradient_Bandit_Algorithm(N=N, T=T, theta_oracled=theta_oracled, b_beta_list=[(-1, 0.5)], trajectory_path=None)

vanilla_ucb_30()
vanilla_gradient_bandit_30()
report_regrets([vanilla_ucb_30])
report_regrets([vanilla_gradient_bandit_30])
# Out:
# Running UCB Algorithm...
# 100%|██████████| 100/100 [00:38<00:00,  2.62it/s]
# Running Gradient Bandit Algorithm...
# 100%|██████████| 100/100 [01:12<00:00,  1.38it/s]

# %% [markdown]
# ## MABs with additional offline data no diff, 20 arms

# %%
import numpy as np
from nonbern_bandit_algorithms import UCB_Algorithm, Offline_Policy_Gradient_Algorithm
from nonbern_bandit_algorithms import report_regrets
N, T = 50000, 100

# set seed
np.random.seed(0)

K = 20
theta_oracled = [(0.85,0.1),(0.8,0.1),(0.75,0.1),(0.7,0.1),(0.65,0.1),(0.6,0.1),(0.55,0.1),(0.5,0.1),(0.45,0.1),(0.4,0.1),(0.35,0.15),(0.3,0.15),(0.25,0.15),(0.2,0.15),(0.15,0.15),(0.1,0.15),(0.08,0.12),(0.06,0.1),(0.04,0.08),(0.02,0.06)]

trajectory_path_no_diff_20 = 'traj_20_nonbern.npy'


ucb_no_diff_20 = UCB_Algorithm(N=N, T=T, theta_oracled=theta_oracled, c_list=[1], trajectory_path=trajectory_path_no_diff_20)
policy_gradient_no_diff_20 = Offline_Policy_Gradient_Algorithm(N=N, T=T, theta_oracled=theta_oracled, b_beta_list=[(-1, 'linear')], trajectory_path=trajectory_path_no_diff_20)

ucb_no_diff_20()
policy_gradient_no_diff_20()

report_regrets([ucb_no_diff_20])
report_regrets([policy_gradient_no_diff_20])
# Out:
# training offline data
# 100%|██████████| 2000/2000 [01:09<00:00, 28.69it/s]
# Policy Gradient trained policy before finetuning:  [-1.75326544e+04 -1.69002448e+04 -1.42973597e+04 -1.23856455e+04
#  -1.38646577e+04 -5.14341396e+03 -7.98291643e+03 -4.31083856e+03
#  -3.42605738e+03 -1.63562603e+00 -1.32612635e+00 -9.24391050e-01
#  -9.55241568e-01 -2.22626487e-01 -3.18760732e-01 -3.79163944e-01
#  -1.35991042e-01 -6.66756047e-01  0.00000000e+00 -8.76152344e-03]
# Running UCB Algorithm...
# 100%|██████████| 100/100 [00:38<00:00,  2.60it/s]
# Running Offline Policy Gradient Algorithm...
# 100%|██████████| 100/100 [01:10<00:00,  1.42it/s]

# %% [markdown]
# ## MABs with additional offline data no diff, 25 arms

# %%
import numpy as np
from nonbern_bandit_algorithms import UCB_Algorithm, Offline_Policy_Gradient_Algorithm
from nonbern_bandit_algorithms import report_regrets
N, T = 50000, 100

# set seed
np.random.seed(0)

K = 25
theta_oracled = [(0.88,0.07),(0.85,0.07),(0.82,0.07),(0.79,0.07),(0.76,0.07),(0.73,0.07),(0.7,0.1),(0.67,0.1),(0.64,0.1),(0.61,0.1),(0.58,0.1),(0.55,0.1),(0.52,0.1),(0.49,0.1),(0.46,0.1),(0.43,0.1),(0.4,0.15),(0.35,0.15),(0.3,0.15),(0.25,0.15),(0.2,0.15),(0.15,0.15),(0.1,0.1),(0.06,0.08),(0.03,0.05)]

trajectory_path_no_diff_25 = 'traj_25_nonbern.npy'


ucb_no_diff_25 = UCB_Algorithm(N=N, T=T, theta_oracled=theta_oracled, c_list=[1], trajectory_path=trajectory_path_no_diff_25)
policy_gradient_no_diff_25 = Offline_Policy_Gradient_Algorithm(N=N, T=T, theta_oracled=theta_oracled, b_beta_list=[(-1, 'linear')], trajectory_path=trajectory_path_no_diff_25)

ucb_no_diff_25()
policy_gradient_no_diff_25()

report_regrets([ucb_no_diff_25])
report_regrets([policy_gradient_no_diff_25])
# Out:
# training offline data
# 100%|██████████| 2000/2000 [01:09<00:00, 28.67it/s]
# Policy Gradient trained policy before finetuning:  [-1.43232789e+04 -1.07029673e+04 -1.23154397e+04 -9.28675989e+03
#  -8.63236674e+03 -1.14828956e+04 -6.78019845e+03 -4.92140284e+03
#  -1.75047222e+03 -5.31648776e+03 -1.37944990e+03 -1.72574329e+03
#  -2.42242488e+00 -2.21951919e+00 -9.45337808e-01 -1.25393077e+00
#  -9.50379886e-01 -1.73080958e+00 -8.59518522e-01  0.00000000e+00
#  -6.53622290e-01 -9.48200879e-01 -2.23843803e-01 -2.62337910e-01
#  -7.33302381e-02]
# Running UCB Algorithm...
# 100%|██████████| 100/100 [00:38<00:00,  2.60it/s]
# Running Offline Policy Gradient Algorithm...
# 100%|██████████| 100/100 [01:12<00:00,  1.37it/s]

# %% [markdown]
# ## MABs with additional offline data no diff, 30 arms

# %%
import numpy as np
from nonbern_bandit_algorithms import UCB_Algorithm, Offline_Policy_Gradient_Algorithm
from nonbern_bandit_algorithms import report_regrets
N, T = 50000, 100

# set seed
np.random.seed(0)

K = 30
theta_oracled = [(0.9,0.05),(0.87,0.05),(0.84,0.05),(0.81,0.05),(0.78,0.05),(0.75,0.05),(0.72,0.05),(0.69,0.07),(0.66,0.07),(0.63,0.07),(0.6,0.07),(0.57,0.07),(0.54,0.07),(0.51,0.07),(0.48,0.1),(0.45,0.1),(0.42,0.1),(0.39,0.1),(0.36,0.1),(0.33,0.1),(0.3,0.1),(0.27,0.1),(0.24,0.1),(0.21,0.1),(0.18,0.1),(0.15,0.1),(0.12,0.08),(0.09,0.08),(0.06,0.06),(0.03,0.04)]

trajectory_path_no_diff_30 = 'traj_30_nonbern.npy'


ucb_no_diff_30 = UCB_Algorithm(N=N, T=T, theta_oracled=theta_oracled, c_list=[1], trajectory_path=trajectory_path_no_diff_30)
policy_gradient_no_diff_30 = Offline_Policy_Gradient_Algorithm(N=N, T=T, theta_oracled=theta_oracled, b_beta_list=[(-1, 'linear')], trajectory_path=trajectory_path_no_diff_30)

ucb_no_diff_30()
policy_gradient_no_diff_30()

report_regrets([ucb_no_diff_30])
report_regrets([policy_gradient_no_diff_30])
# Out:
# training offline data
# 100%|██████████| 2000/2000 [01:11<00:00, 27.88it/s]
# Policy Gradient trained policy before finetuning:  [-6.00028698e+02 -1.29451901e+03 -2.23385068e+00 -7.37659297e+02
#  -3.70043045e+00 -2.35899300e+00 -2.65578088e+00 -8.42705145e+02
#  -2.61447308e+00 -2.16007148e+00 -1.88943763e+00 -1.44073472e+00
#  -1.82075694e+00 -1.09981624e+00 -2.11530667e+00 -1.82087815e+00
#  -7.27412477e-01 -1.48670522e+00 -1.63281784e+00 -1.29136327e+00
#  -7.03801803e-01 -4.15659542e-01 -6.48453365e-01 -4.08553745e-01
#  -5.01402198e-01  0.00000000e+00 -5.11626740e-01 -2.87582606e-01
#  -1.12175875e-01 -1.20880036e-01]
# Running UCB Algorithm...
# 100%|██████████| 100/100 [00:38<00:00,  2.57it/s]
# Running Offline Policy Gradient Algorithm...
# 100%|██████████| 100/100 [01:16<00:00,  1.31it/s]

# %% [markdown]
# ## MABs with additional offline data generated by diffusion model (seq, transformer) 20 arms

# %%
import numpy as np
from nonbern_bandit_algorithms import UCB_Algorithm, Offline_Policy_Gradient_Algorithm
from nonbern_bandit_algorithms import report_regrets
N, T = 50000, 100

# set seed
np.random.seed(0)

K = 20
theta_oracled = [(0.85,0.1),(0.8,0.1),(0.75,0.1),(0.7,0.1),(0.65,0.1),(0.6,0.1),(0.55,0.1),(0.5,0.1),(0.45,0.1),(0.4,0.1),(0.35,0.15),(0.3,0.15),(0.25,0.15),(0.2,0.15),(0.15,0.15),(0.1,0.15),(0.08,0.12),(0.06,0.1),(0.04,0.08),(0.02,0.06)]

trajectory_path_diff_20 = 'traj_20_nonbern_diff.npy'


ucb_diff_20 = UCB_Algorithm(N=N, T=T, theta_oracled=theta_oracled, c_list=[1], trajectory_path=trajectory_path_diff_20)
policy_gradient_diff_20 = Offline_Policy_Gradient_Algorithm(N=N, T=T, theta_oracled=theta_oracled, b_beta_list=[(-1, 'linear')], trajectory_path=trajectory_path_diff_20)

ucb_diff_20()
policy_gradient_diff_20()

report_regrets([ucb_diff_20])
report_regrets([policy_gradient_diff_20])
# Out:
# training offline data
# 100%|██████████| 2000/2000 [06:56<00:00,  4.81it/s]
# Policy Gradient trained policy before finetuning:  [-3.37945155e+04 -3.17173872e+04 -2.67287487e+04 -2.96110862e+04
#  -2.28092897e+04 -2.42690462e+04 -2.15462497e+04 -1.58566140e+04
#  -1.43083928e+04 -8.85415056e+03 -1.18822038e+04 -1.21039880e+04
#  -7.95551480e+03 -7.59006537e+00 -4.01507452e+00 -2.25631445e+00
#  -3.75081060e+00 -2.95156258e+00 -1.70434739e+00  0.00000000e+00]
# Running UCB Algorithm...
# 100%|██████████| 100/100 [00:38<00:00,  2.62it/s]
# Running Offline Policy Gradient Algorithm...
# 100%|██████████| 100/100 [01:09<00:00,  1.44it/s]

# %% [markdown]
# ## MABs with additional offline data generated by diffusion model (seq, transformer) 25 arms

# %%
import numpy as np
from nonbern_bandit_algorithms import UCB_Algorithm, Offline_Policy_Gradient_Algorithm
from nonbern_bandit_algorithms import report_regrets
N, T = 50000, 100

# set seed
np.random.seed(0)

K = 25
theta_oracled = [(0.88,0.07),(0.85,0.07),(0.82,0.07),(0.79,0.07),(0.76,0.07),(0.73,0.07),(0.7,0.1),(0.67,0.1),(0.64,0.1),(0.61,0.1),(0.58,0.1),(0.55,0.1),(0.52,0.1),(0.49,0.1),(0.46,0.1),(0.43,0.1),(0.4,0.15),(0.35,0.15),(0.3,0.15),(0.25,0.15),(0.2,0.15),(0.15,0.15),(0.1,0.1),(0.06,0.08),(0.03,0.05)]

trajectory_path_diff_25 = 'traj_25_nonbern_diff.npy'


ucb_diff_25 = UCB_Algorithm(N=N, T=T, theta_oracled=theta_oracled, c_list=[1], trajectory_path=trajectory_path_diff_25)
policy_gradient_diff_25 = Offline_Policy_Gradient_Algorithm(N=N, T=T, theta_oracled=theta_oracled, b_beta_list=[(-1, 'linear')], trajectory_path=trajectory_path_diff_25)

ucb_diff_25()
policy_gradient_diff_25()

report_regrets([ucb_diff_25])
report_regrets([policy_gradient_diff_25])
# Out:
# training offline data
# 100%|██████████| 2000/2000 [06:55<00:00,  4.81it/s]
# Policy Gradient trained policy before finetuning:  [-1.84670617e+04 -2.08175526e+04 -1.79519090e+04 -2.06816824e+04
#  -2.02847038e+04 -1.61059938e+04 -1.95503243e+04 -2.12087082e+04
#  -1.42076405e+04 -1.43180932e+04 -1.29216720e+04 -1.01087192e+04
#  -1.03368430e+04 -7.88144841e+03 -1.90669649e+03 -6.87792841e+02
#  -5.16495680e+03 -3.64131702e+03 -8.32456597e+00 -1.21880416e+01
#  -4.16390527e+00 -3.17493838e+00 -4.75092917e+00 -1.80576287e+00
#   0.00000000e+00]
# Running UCB Algorithm...
# 100%|██████████| 100/100 [00:38<00:00,  2.61it/s]
# Running Offline Policy Gradient Algorithm...
# 100%|██████████| 100/100 [01:12<00:00,  1.38it/s]

# %% [markdown]
# ## MABs with additional offline data generated by diffusion model (seq, transformer) 30 arms

# %%
import numpy as np
from nonbern_bandit_algorithms import UCB_Algorithm, Offline_Policy_Gradient_Algorithm
from nonbern_bandit_algorithms import report_regrets
N, T = 50000, 100

# set seed
np.random.seed(0)

K = 30
theta_oracled = [(0.9,0.05),(0.87,0.05),(0.84,0.05),(0.81,0.05),(0.78,0.05),(0.75,0.05),(0.72,0.05),(0.69,0.07),(0.66,0.07),(0.63,0.07),(0.6,0.07),(0.57,0.07),(0.54,0.07),(0.51,0.07),(0.48,0.1),(0.45,0.1),(0.42,0.1),(0.39,0.1),(0.36,0.1),(0.33,0.1),(0.3,0.1),(0.27,0.1),(0.24,0.1),(0.21,0.1),(0.18,0.1),(0.15,0.1),(0.12,0.08),(0.09,0.08),(0.06,0.06),(0.03,0.04)]

trajectory_path_diff_30 = 'traj_30_nonbern_diff.npy'


ucb_diff_30 = UCB_Algorithm(N=N, T=T, theta_oracled=theta_oracled, c_list=[1], trajectory_path=trajectory_path_diff_30)
policy_gradient_diff_30 = Offline_Policy_Gradient_Algorithm(N=N, T=T, theta_oracled=theta_oracled, b_beta_list=[(-1, 'linear')], trajectory_path=trajectory_path_diff_30)

ucb_diff_30()
policy_gradient_diff_30()

report_regrets([ucb_diff_30])
report_regrets([policy_gradient_diff_30])
# Out:
# training offline data
# 100%|██████████| 2000/2000 [06:59<00:00,  4.77it/s]
# Policy Gradient trained policy before finetuning:  [-8.36806928e+03 -1.21998129e+04 -5.75074104e+03 -9.86007362e+03
#  -7.57758992e+03 -8.90305921e+03 -1.11877433e+04 -8.77638402e+03
#  -7.40179836e+03 -6.65834494e+03 -5.72862242e+03 -7.07229597e+03
#  -6.21593549e+03 -4.37120519e+03 -7.07767053e+03 -7.42946536e+03
#  -1.20151346e+03 -1.03554463e+01 -4.59095797e+00 -1.44930819e+02
#  -3.53350134e+00 -5.51631691e+00 -2.27900219e+00 -2.24778897e+00
#  -7.46430887e-01 -2.32349781e+00 -2.13257107e-01 -5.48342882e-01
#  -2.91668025e-01  0.00000000e+00]
# Running UCB Algorithm...
# 100%|██████████| 100/100 [00:37<00:00,  2.63it/s]
# Running Offline Policy Gradient Algorithm...
# 100%|██████████| 100/100 [01:15<00:00,  1.33it/s]

# %% [markdown]
# ## Report results

# %%
from nonbern_bandit_algorithms import overall_analysis
algorithms = [  (vanilla_ucb_20, 'UCB no pretrain 20'),
                (vanilla_gradient_bandit_20, 'gradient no pretrain 20'),
                (vanilla_ucb_25, 'UCB no pretrain 25'),
                (vanilla_gradient_bandit_25, 'gradient no pretrain 25'),
                (vanilla_ucb_30, 'UCB no pretrain 30'),
                (vanilla_gradient_bandit_30, 'gradient no pretrain 30'),
                (ucb_no_diff_20, 'UCB no diff 20'),
                (policy_gradient_no_diff_20, 'gradient no diff 20'),
                (ucb_no_diff_25, 'UCB no diff 25'),
                (policy_gradient_no_diff_25, 'gradient no diff 25'),
                (ucb_no_diff_30, 'UCB no diff 30'),
                (policy_gradient_no_diff_30, 'gradient no diff 30'),
                (ucb_diff_20, 'UCB diff 20'),
                (policy_gradient_diff_20, 'gradient diff 20'),
                (ucb_diff_25, 'UCB diff 25'),
                (policy_gradient_diff_25, 'gradient diff 25'),
                (ucb_diff_30, 'UCB diff 30'),
                (policy_gradient_diff_30, 'gradient diff 30'),
            ]
overall_analysis(algorithms)
# Out:
# UCB no pretrain 20             : 1351.033
# gradient no pretrain 20        : 742.086
# UCB no pretrain 25             : 1288.369
# gradient no pretrain 25        : 964.330
# UCB no pretrain 30             : 1700.104
# gradient no pretrain 30        : 1040.903
# UCB no diff 20                 : 719.629
# gradient no diff 20            : 249.610
# UCB no diff 25                 : 465.870
# gradient no diff 25            : 186.230
# UCB no diff 30                 : 721.866
# gradient no diff 30            : 406.857
# UCB diff 20                    : 16.517
# gradient diff 20               : 0.000
# UCB diff 25                    : 12.220
# gradient diff 25               : 0.000
# UCB diff 30                    : 119.548
# gradient diff 30               : 6.077
